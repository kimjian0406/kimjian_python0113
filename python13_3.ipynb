# %% [markdown]
# [문제]
#
# 'Book' 클래스를 선언하세요.
#
# 이 클래스는 title (제목)과 author (저자) 두 개의 속성을 갖습니다.
#
# __str__ 특수 메소드를 오버라이드하여, 객체를 문자열로 변환할 때 "제목: [title], 저자: [author]" 형식의 문자열을 반환하도록 하세요.
#
# 'Book' 객체를 하나 생성하고, print 함수를 사용하여 해당 객체의 문자열 표현을 출력하세요.

# %%
class Book:
    def __init__(self, title, author):
        """
        Book 클래스의 생성자. 제목과 저자를 초기화합니다.
        :param title: 책의 제목
        :param author: 책의 저자
        """
        self.title = title
        self.author = author

    def describe_book(self):
        """
        책의 제목과 저자를 출력합니다.
        """
        print(f"제목: {self.title}, 저자: {self.author}")


# Book 객체 생성
my_book = Book("모든 이들이 고래가 된다면", "안델리카안")

# 책 정보 출력
my_book.describe_book()
# Out:
# 제목: 모든 이들이 고래가 된다면, 저자: 안델리카안
